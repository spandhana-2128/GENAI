# %% [markdown]
# # **1a**

# %%
# %pip install python-dotenv --upgrade --quiet langchain langchain-google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.5/500.5 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.1/158.1 kB 3.2 MB/s eta 0:00:00

# %%
from dotenv import load_dotenv
load_dotenv()

import getpass
import os

if "GOOGLE_API_KEY" not in os.environ:
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API Key: ")
# Out:
# Enter your Google API Key: ··········

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm_focused = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.0)
llm_creative = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=1.0)

# %%
prompt = "Define the word 'Idea' in one sentence."
print("---FOCUSED (Temp=0) ---")
print(f"Run 1 : {llm_focused.invoke(prompt).content}")
print(f"Run 2 : {llm_focused.invoke(prompt).content}")
# Out:
# ---FOCUSED (Temp=0) ---
# Run 1 : An idea is a thought, concept, or mental image formed in the mind.
# Run 2 : An idea is a thought, concept, or suggestion that is formed or exists in the mind.

# %%
print("--- CREATIVE (Temp=1) ---")
print(f"Run 1: {llm_creative.invoke(prompt).content}")
print(f"Run 2: {llm_creative.invoke(prompt).content}")
# Out:
# --- CREATIVE (Temp=1) ---
# Run 1: An idea is a concept, thought, or mental impression existing in the mind.
# Run 2: An idea is a mental construct or conception formulated in the mind, often representing a thought, plan, or solution.

# %% [markdown]
# # **1b**

# %%
from dotenv import load_dotenv
load_dotenv()

import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI

if "GOOGLE_API_KEY" not in os.environ:
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API Key: ")

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
from langchain_core.messages import SystemMessage, HumanMessage
messages = (
    SystemMessage(content="You are a teacher who teaches 7th graders"),
    HumanMessage(content="What is the capital of France?")
)

response = llm.invoke(messages)
print(response.content)
# Out:
# That's a great question!
#
# The capital of France is **Paris**.

# %%
from langchain_core.prompts import ChatPromptTemplate

template = ChatPromptTemplate.from_messages([
    ("system", "You are a translator. Translate {input_language} to {output_language}."),
    ("human", "{text}")
])

# We can check what inputs it expects
print(f"Required variables: {template.input_variables}")
# Out:
# Required variables: ['input_language', 'output_language', 'text']

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

# Raw Message
raw_msg = llm.invoke("Hi")
print(f"Raw Type: {type(raw_msg)}")

# Parsed String
clean_text = parser.invoke(raw_msg)
print(f"Parsed Type: {type(clean_text)}")
print(f"Content: {clean_text}")
# Out:
# Raw Type: <class 'langchain_core.messages.ai.AIMessage'>
# Parsed Type: <class 'langchain_core.messages.base.TextAccessor'>
# Content: Hello! How can I help you today?

# %% [markdown]
# # **1c**

# %%
from dotenv import load_dotenv
load_dotenv()

import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

if "GOOGLE_API_KEY" not in os.environ:
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API Key: ")

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
template = ChatPromptTemplate.from_template("Tell me a fact about {topic}.")
parser = StrOutputParser()

# %%
prompt_value = template.invoke({"topic": "Candy"})
response_obj = llm.invoke(prompt_value)
final_text = parser.invoke(response_obj)
print(final_text)
# Out:
# The word "candy" comes from the Arabic word **"qandi"**, which refers to crystallized sugar. This in turn is derived from the Persian **"kand"**, and ultimately from the Sanskrit word **"khaṇḍa"**, meaning "a piece of sugar."

# %%
chain = template | llm | parser
print(chain.invoke({"topic": "Whales"}))
# Out:
# The **blue whale** is the largest animal on Earth, growing up to 98 feet (30 meters) long and weighing as much as 200 tons (about 400,000 pounds). Its heart alone can be the size of a small car!

# %% [markdown]
# # **ASSIGNMENT**

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

chain = (
    ChatPromptTemplate.from_template(
        "The movie '{movie}' was released in which year? "
        "Also calculate how many years ago that was from 2026."
    )
    | llm
    | StrOutputParser()
)

print(chain.invoke({"movie": "The Maze Runner"}))
# Out:
# The movie 'The Maze Runner' was released in **2014**.
#
# From 2026, that was **12 years ago** (2026 - 2014 = 12).
